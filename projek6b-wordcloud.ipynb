# %%
import pandas as pd

df = pd.read_csv('Dataset/jobstreet_3000_hasillabeling.csv')
df.head()
# Out:
#           userName  score                   at  \
# 0  Pengguna Google      1  2024-12-12 08:14:23
# 1  Pengguna Google      3  2024-12-12 07:29:09
# 2  Pengguna Google      2  2024-12-12 04:27:59
# 3  Pengguna Google      1  2024-12-11 23:41:41
# 4  Pengguna Google      1  2024-12-11 22:51:25
#
#                                              content  \
# 0  Setiap apply lamaran disini, bbrpa hari atau b...
# 1  min tolong ini ngebug, masa pas mau buka lowon...
# 2                                           Worth it
# 3           Jadi susah re login by seek, gagal terus
# 4  TOLONG DI PERBAIKI MASALAH YANG ADA DI APLIKAS...
#
#                                           text_clean  \
# 0  setiap apply lamaran disini bbrpa hari atau bb...
# 1  min tolong ini ngebug masa pas mau buka lowong...
# 2                                           worth it
# 3            jadi susah re login by seek gagal terus
# 4  tolong di perbaiki masalah yang ada di aplikas...
#
#                                        text_Stopword  \
# 0  apply lamaran bbrpa bbrpa minggu balasan stiap...
# 1  min tolong ngebug pas buka lowongan muter mute...
# 2                                           worth it
# 3                       susah re login by seek gagal
# 4  tolong perbaiki aplikasi login eror gausah sur...
#
#                                          text_tokens  \
# 0  ['apply', 'lamaran', 'bbrpa', 'bbrpa', 'minggu...
# 1  ['min', 'tolong', 'ngebug', 'pas', 'buka', 'lo...
# 2                                    ['worth', 'it']
# 3    ['susah', 're', 'login', 'by', 'seek', 'gagal']
# 4  ['tolong', 'perbaiki', 'aplikasi', 'login', 'e...
#
#                                  text_tokens_stemmed    Label
# 0  apply lamar bbrpa bbrpa minggu balas stiap per...  negatif
# 1  min tolong ngebug pas buka lowong muter muter ...      NaN
# 2                                           worth it  negatif
# 3                       susah re login by seek gagal  negatif
# 4  tolong baik aplikasi login eror gausah suruh s...  negatif

# %%
my_df = df.sort_values(by=['at'], ascending=False)
my_df.head()
# Out:
#           userName  score                   at  \
# 0  Pengguna Google      1  2024-12-12 08:14:23
# 1  Pengguna Google      3  2024-12-12 07:29:09
# 2  Pengguna Google      2  2024-12-12 04:27:59
# 3  Pengguna Google      1  2024-12-11 23:41:41
# 4  Pengguna Google      1  2024-12-11 22:51:25
#
#                                              content  \
# 0  Setiap apply lamaran disini, bbrpa hari atau b...
# 1  min tolong ini ngebug, masa pas mau buka lowon...
# 2                                           Worth it
# 3           Jadi susah re login by seek, gagal terus
# 4  TOLONG DI PERBAIKI MASALAH YANG ADA DI APLIKAS...
#
#                                           text_clean  \
# 0  setiap apply lamaran disini bbrpa hari atau bb...
# 1  min tolong ini ngebug masa pas mau buka lowong...
# 2                                           worth it
# 3            jadi susah re login by seek gagal terus
# 4  tolong di perbaiki masalah yang ada di aplikas...
#
#                                        text_Stopword  \
# 0  apply lamaran bbrpa bbrpa minggu balasan stiap...
# 1  min tolong ngebug pas buka lowongan muter mute...
# 2                                           worth it
# 3                       susah re login by seek gagal
# 4  tolong perbaiki aplikasi login eror gausah sur...
#
#                                          text_tokens  \
# 0  ['apply', 'lamaran', 'bbrpa', 'bbrpa', 'minggu...
# 1  ['min', 'tolong', 'ngebug', 'pas', 'buka', 'lo...
# 2                                    ['worth', 'it']
# 3    ['susah', 're', 'login', 'by', 'seek', 'gagal']
# 4  ['tolong', 'perbaiki', 'aplikasi', 'login', 'e...
#
#                                  text_tokens_stemmed    Label
# 0  apply lamar bbrpa bbrpa minggu balas stiap per...  negatif
# 1  min tolong ngebug pas buka lowong muter muter ...      NaN
# 2                                           worth it  negatif
# 3                       susah re login by seek gagal  negatif
# 4  tolong baik aplikasi login eror gausah suruh s...  negatif

# %%
my_df.head()
# Out:
#           userName  score                   at  \
# 0  Pengguna Google      1  2024-12-12 08:14:23
# 1  Pengguna Google      3  2024-12-12 07:29:09
# 2  Pengguna Google      2  2024-12-12 04:27:59
# 3  Pengguna Google      1  2024-12-11 23:41:41
# 4  Pengguna Google      1  2024-12-11 22:51:25
#
#                                              content  \
# 0  Setiap apply lamaran disini, bbrpa hari atau b...
# 1  min tolong ini ngebug, masa pas mau buka lowon...
# 2                                           Worth it
# 3           Jadi susah re login by seek, gagal terus
# 4  TOLONG DI PERBAIKI MASALAH YANG ADA DI APLIKAS...
#
#                                           text_clean  \
# 0  setiap apply lamaran disini bbrpa hari atau bb...
# 1  min tolong ini ngebug masa pas mau buka lowong...
# 2                                           worth it
# 3            jadi susah re login by seek gagal terus
# 4  tolong di perbaiki masalah yang ada di aplikas...
#
#                                        text_Stopword  \
# 0  apply lamaran bbrpa bbrpa minggu balasan stiap...
# 1  min tolong ngebug pas buka lowongan muter mute...
# 2                                           worth it
# 3                       susah re login by seek gagal
# 4  tolong perbaiki aplikasi login eror gausah sur...
#
#                                          text_tokens  \
# 0  ['apply', 'lamaran', 'bbrpa', 'bbrpa', 'minggu...
# 1  ['min', 'tolong', 'ngebug', 'pas', 'buka', 'lo...
# 2                                    ['worth', 'it']
# 3    ['susah', 're', 'login', 'by', 'seek', 'gagal']
# 4  ['tolong', 'perbaiki', 'aplikasi', 'login', 'e...
#
#                                  text_tokens_stemmed    Label
# 0  apply lamar bbrpa bbrpa minggu balas stiap per...  negatif
# 1  min tolong ngebug pas buka lowong muter muter ...      NaN
# 2                                           worth it  negatif
# 3                       susah re login by seek gagal  negatif
# 4  tolong baik aplikasi login eror gausah suruh s...  negatif

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   userName             3000 non-null   object
#  1   score                3000 non-null   int64
#  2   at                   3000 non-null   object
#  3   content              3000 non-null   object
#  4   text_clean           2988 non-null   object
#  5   text_Stopword        2966 non-null   object
#  6   text_tokens          3000 non-null   object
#  7   text_tokens_stemmed  2966 non-null   object
#  8   Label                2753 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 211.1+ KB

# %%
my_df.isna()
# Out:
#       userName  score     at  content  text_clean  text_Stopword  text_tokens  \
# 0        False  False  False    False       False          False        False
# 1        False  False  False    False       False          False        False
# 2        False  False  False    False       False          False        False
# 3        False  False  False    False       False          False        False
# 4        False  False  False    False       False          False        False
# ...        ...    ...    ...      ...         ...            ...          ...
# 2995     False  False  False    False       False          False        False
# 2996     False  False  False    False       False          False        False
# 2997     False  False  False    False       False          False        False
# 2998     False  False  False    False       False          False        False
# 2999     False  False  False    False       False          False        False
#
#       text_tokens_stemmed  Label
# 0                   False  False
# 1                   False   True
# 2                   False  False
# 3                   False  False
# 4                   False  False
# ...                   ...    ...
# 2995                False  False
# 2996                False  False
# 2997                False  False
# 2998                False  False
# 2999                False  False
#
# [3000 rows x 9 columns]

# %%
my_df.isna().any()
# Out:
# userName               False
# score                  False
# at                     False
# content                False
# text_clean              True
# text_Stopword           True
# text_tokens            False
# text_tokens_stemmed     True
# Label                   True
# dtype: bool

# %%
my_df.describe()
# Out:
#              score
# count  3000.000000
# mean      3.169667
# std       1.782116
# min       1.000000
# 25%       1.000000
# 50%       4.000000
# 75%       5.000000
# max       5.000000

# %%
my_df.isnull().sum()
# Out:
# userName                 0
# score                    0
# at                       0
# content                  0
# text_clean              12
# text_Stopword           34
# text_tokens              0
# text_tokens_stemmed     34
# Label                  247
# dtype: int64

# %% [markdown]
# # Wordcloud Klasifikasi Sentimen Semua

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Fungsi untuk memplot wordcloud
def plot_cloud(wordcloud):
    plt.figure(figsize=(10, 8))  # Atur ukuran plot
    plt.imshow(wordcloud, interpolation='bilinear')  # Tampilkan wordcloud
    plt.axis('off')  # Hilangkan sumbu

    # Simpan plot ke file
    plt.savefig('wordcloud_output_netral.png', bbox_inches='tight')  # Simpan dengan nama file

    plt.show()  # Tampilkan plot

# # Filter data untuk hanya menyertakan tweet positif
# netral_tweets = my_df[my_df['Label'] == 'None']

# # Gabungkan semua kata dalam kolom 'full_text' dari tweet positif menjadi satu string
# netral_words = ' '.join([tweets for tweets in netral_tweets['content']])

# Gabungkan semua kata dalam kolom 'full_text' menjadi satu string
all_words = ' '.join([tweets for tweets in my_df['content']])

# Buat wordcloud untuk kata-kata positif
wordcloud = WordCloud(
    width=3000,
    height=2000,
    random_state=3,
    background_color='black',
    colormap='Blues_r',
    collocations=False,
    stopwords=STOPWORDS  # Hindari kata umum yang ada di STOPWORDS
).generate(all_words)

# Plot wordcloud yang telah dibuat
plot_cloud(wordcloud)

# %% [markdown]
# # Wordcloud Klasifikasi Sentimen Positif

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Fungsi untuk memplot wordcloud
def plot_cloud(wordcloud):
    plt.figure(figsize=(10, 8))  # Atur ukuran plot
    plt.imshow(wordcloud, interpolation='bilinear')  # Tampilkan wordcloud
    plt.axis('off')  # Hilangkan sumbu

    # Simpan plot ke file
    plt.savefig('wordcloud_output_netral.png', bbox_inches='tight')  # Simpan dengan nama file

    plt.show()  # Tampilkan plot

# # Filter data untuk hanya menyertakan tweet positif
netral_tweets = my_df[my_df['Label'] == 'positif']

# # Gabungkan semua kata dalam kolom 'full_text' dari tweet positif menjadi satu string
netral_words = ' '.join([tweets for tweets in netral_tweets['content']])

# # Gabungkan semua kata dalam kolom 'full_text' menjadi satu string
# all_words = ' '.join([tweets for tweets in my_df['content']])

# Buat wordcloud untuk kata-kata positif
wordcloud = WordCloud(
    width=3000,
    height=2000,
    random_state=3,
    background_color='black',
    colormap='Blues_r',
    collocations=False,
    stopwords=STOPWORDS  # Hindari kata umum yang ada di STOPWORDS
).generate(netral_words)

# Plot wordcloud yang telah dibuat
plot_cloud(wordcloud)

# %% [markdown]
# # Wordcloud Klasifikasi Sentimen Negatif

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Fungsi untuk memplot wordcloud
def plot_cloud(wordcloud):
    plt.figure(figsize=(10, 8))  # Atur ukuran plot
    plt.imshow(wordcloud, interpolation='bilinear')  # Tampilkan wordcloud
    plt.axis('off')  # Hilangkan sumbu

    # Simpan plot ke file
    plt.savefig('wordcloud_output_netral.png', bbox_inches='tight')  # Simpan dengan nama file

    plt.show()  # Tampilkan plot

# # Filter data untuk hanya menyertakan tweet positif
netral_tweets = my_df[my_df['Label'] == 'negatif']

# # Gabungkan semua kata dalam kolom 'full_text' dari tweet positif menjadi satu string
netral_words = ' '.join([tweets for tweets in netral_tweets['content']])

# # Gabungkan semua kata dalam kolom 'full_text' menjadi satu string
# all_words = ' '.join([tweets for tweets in my_df['content']])

# Buat wordcloud untuk kata-kata positif
wordcloud = WordCloud(
    width=3000,
    height=2000,
    random_state=3,
    background_color='black',
    colormap='Blues_r',
    collocations=False,
    stopwords=STOPWORDS  # Hindari kata umum yang ada di STOPWORDS
).generate(netral_words)

# Plot wordcloud yang telah dibuat
plot_cloud(wordcloud)
